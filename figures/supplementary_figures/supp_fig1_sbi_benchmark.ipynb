# %% [markdown]
# # Supp. figure 1: Evaluation of SBI
#
# The figure shows the results for evaluating SBI.
#
# The training data and inference objects are pre computed and only loaded for visualization in this notebook.
#
# For details on how to perform inference, see `/tutorials` or `/scripts`

# %%
from sbibm.utils.io import get_tensor_from_csv
import pandas as pd
import altair as alt
from scipy.stats import binom

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
from sbi.analysis import pairplot
import sbibm
import pickle
import matplotlib
from scipy.stats import gaussian_kde

from consbi import DATA_PATH, RESULTS_PATH

# matplotlib.rcParams.update({'figure.autolayout': True})
plt.style.use('../plotting_settings.mplstyle')

# set KDE values
num_bins = 100
bw_method = 0.3

# Colorblind color palette
colors = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Select data

# %%
path_poisson_samples = RESULTS_PATH.joinpath("benchmark_poisson_glm_snpe_samples")
path_poisson_benchmark = RESULTS_PATH.joinpath("benchmark_poisson_glm_SABC_SNPE.p")

path_sbc_fullmodel = RESULTS_PATH.joinpath("sbc_results_npe_ss50_N1006.p")
path_ppc_fullmodel = RESULTS_PATH.joinpath("posterior_predictive_npe_ss50_ths_xs.p")

# %%
task = sbibm.get_task("poisson_glm")
obs = 5
ths_ref = task.get_reference_posterior_samples(obs)
tho = task.get_true_parameters(obs)
xo = task.get_observation(obs)
ths_prior = task.get_prior_dist().sample((1000,))

ths = get_tensor_from_csv(path_poisson_samples.joinpath("posterior_samples.csv.bz2"))
xs = get_tensor_from_csv(path_poisson_samples.joinpath("predictive_samples.csv.bz2"))

# SBC results full model
with open(path_sbc_fullmodel, "rb") as fh:
    N2, ranks2, L2, *_ = pickle.load(fh).values()
    
# Benchmark results:
# NOTE: Choose result based on prior!
with open(path_poisson_benchmark, "rb") as fh:
    df, means, stds, benchmark_labels, num_simulations, num_observations = pickle.load(fh).values()
    
# PPCs full model
with open(path_ppc_fullmodel, "rb") as fh:
    prior, posterior, tho2, xo2, ths2, xs2, ths_prior2, xs_prior2, xos2 = pickle.load(fh).values()
# tho2[0, -1] *= -1 
# NOTE: sampling does not work with new version of SBI. 
# ths2 = posterior.sample((ths.shape[0],), x=xo2)
means = means.squeeze()
stds = stds.squeeze()

# ths2[:, 2] *= -1

# %% [markdown]
# ### Plotting helper functions

# %%
def plot_sbc(ranks, num_bins, alpha=.8, num_ticks=3, color="C0", 
             ranks_label=None, num_repeats=50, show_ylabel=True, 
             show_legend=False, xlabel=None, plot_uniform_region=False,
             legend_kwargs={},
            ):
    
    # Generate histogram of ranks.
    hist, *_ = np.histogram(ranks, bins=num_bins, density=False)
    # Construct empirical CDF.
    histcs = hist.cumsum()
    # Plot cdf and repeat each stair step
    plt.plot(
        np.linspace(0, num_bins, num_repeats * num_bins),
        np.repeat(histcs / histcs.max(), num_repeats),
        label=ranks_label,
        color=color,
        alpha=alpha,
    )

    if show_ylabel:
        plt.yticks(np.linspace(0, 1, 3))
        plt.ylabel("empirical CDF")
    else:
        # Plot ticks only
        plt.yticks(np.linspace(0, 1, 3), [])
    if show_legend and ranks_label:
        plt.legend(**legend_kwargs)

    plt.ylim(0, 1)
    plt.xlim(0, num_bins)
    plt.xticks(np.linspace(0, num_bins, num_ticks))
    plt.xlabel("posterior rank" if xlabel is None else xlabel)
    
    if plot_uniform_region:
        # Construct uniform histogram.
        num_sbc_runs = ranks.shape[0]
        uni_bins = binom(num_sbc_runs, p=1 / num_bins).ppf(0.5) * np.ones(num_bins)
        uni_bins_cdf = uni_bins.cumsum() / uni_bins.sum()
        # Decrease value one in last entry by epsilon to find valid
        # confidence intervals.
        uni_bins_cdf[-1] -= 1e-9

        lower = [binom(num_sbc_runs, p=p).ppf(0.005) for p in uni_bins_cdf]
        upper = [binom(num_sbc_runs, p=p).ppf(0.995) for p in uni_bins_cdf]

        # Plot grey area with expected ECDF.
        plt.fill_between(
            x=np.linspace(0, num_bins, num_repeats * num_bins),
            y1=np.repeat(lower / np.max(lower), num_repeats),
            y2=np.repeat(upper / np.max(upper), num_repeats),
            color="grey",
            alpha=0.2,
        )

def plot_benchmark(ax, legend_kwargs={}):
    plt.sca(ax)
    benchmark_labels[2] = "SMC"
    nlines = means.shape[0]
    idxs = [2, 0, 3]
#     NPE, REJ, SMC, SNPE
#     idxs = [3, 0, 2, 1]
    
    cs = [colors[1], "grey", "k", colors[0]]
    alphas = [.8, 0.5, 0.5, .8]
    for i in idxs:
        plt.errorbar(num_simulations, 
                     y=means[i, ], marker='o',
                     yerr=stds[i,:] / np.sqrt(num_observations), 
                     color=cs[i], 
                     alpha=alphas[i],)

    plt.xscale("log")
    plt.yticks(np.linspace(.5, 1, 3))
    # plt.grid(axis='y')
    plt.legend([benchmark_labels[j] for j in idxs], frameon=False, **legend_kwargs);
    plt.ylabel("C2ST")
    plt.xlabel("number of simulations");

# %%
fig = plt.figure(figsize=(18, 7))
super_grid = fig.add_gridspec(1, 2, wspace=0.15, hspace=0, width_ratios=[.36, .64])
height_ratios = [0.6, .4]
num_data = 7
num_params = 3
handlelength = 0.8
alpha = 0.8
num_kde_bins = 100
num_hist_bins = 20
# plot fewer samples for debugging
num_samples = 10000

# left, subplot a
posterior_grid = super_grid[0, 0].subgridspec(num_params, num_params, wspace=0.1, hspace=0.1)
ax1 = posterior_grid.subplots()

# right, benchmark plots and ppc
right_grid = super_grid[0, 1].subgridspec(2, 1, hspace=0.5)

# benchmark
benchmark_grid = right_grid[0, 0].subgridspec(1, 2, wspace=0.5)
benchmark_axs = benchmark_grid.subplots()
ax2 = benchmark_axs[0]
ax3 = benchmark_axs[1]

# ppc
ppc_grid = right_grid[1, 0].subgridspec(1, 7, wspace=0.15)
ppc_axs = ppc_grid.subplots()
ax4 = ppc_axs[0]

param_labels = [r"$\theta_{pre}$", r"$\theta_{post}$", r"$\theta_{postAll}$"]
data_labels = [r"L4", r"L4SEP", r"L4SP", r"L4SS", r"L5IT", r"L5PT", r"L6"]
plt.style.use('../plotting_settings.mplstyle')

# Posteriors
posterior_opts = dict(upper="contour", 
                      diag="kde",
                      contour_offdiag=dict(levels=[0.99]), 
                      points_colors=["k"],
                      points_offdiag=dict(marker="+", markersize=7), 
                      kde_offdiag=dict(bins=num_kde_bins, bw_method=bw_method),
                      kde_diag=dict(bins=num_kde_bins, bw_method=bw_method),
                      labels = param_labels,

           )
fig, ax1 = pairplot([ths_ref[:num_samples], ths[:num_samples]], 
                    points=tho.squeeze(), samples_colors=[colors[2], colors[0]],
                    fig=fig, axes=ax1, 
                    limits=[[-1, 3], [-1, 3], [-1, 3]], 
                    ticks =[[-1, 2]] * 3,
                    **posterior_opts)

plt.sca(ax1[0, 0])
plt.legend(["reference posterior", "SNPE posterior", r"ground-truth $\theta$"], 
           bbox_to_anchor=(-.4, -1.8), 
           handlelength=handlelength,
           loc=2)

# Benchmark
plot_benchmark(ax2, legend_kwargs=dict(handlelength=handlelength, bbox_to_anchor=(0.7, 1.0)))
num_bins = 50
for idx, r in enumerate(ranks2):
    plt.sca(ax3)
    plot_sbc(np.array(r), num_bins=num_bins, 
             show_ylabel=True, color=colors[idx+4], 
             alpha=1.0,
             show_legend=idx==2, 
             ranks_label=param_labels[idx],
             plot_uniform_region=idx==2,
             legend_kwargs=dict(handlelength=handlelength, loc=4, bbox_to_anchor=(1.2, 0.0)),
            )

for ii in range(num_data):
    plt.sca(ppc_axs[ii])
    plt.hist(xs2[:, ii].numpy(), color=colors[1], bins=np.linspace(0, 1, num_hist_bins), alpha=alpha)
    plt.axvline(xo2[0, ii], color="k")
    plt.xticks(np.linspace(0,1,2))
    plt.xlim(0, 1)
    ppc_axs[ii].spines["right"].set_visible(False)
    ppc_axs[ii].spines["top"].set_visible(False)
    ppc_axs[ii].spines["left"].set_visible(False)
    plt.yticks([])
    plt.xlabel(data_labels[ii])
    
plt.legend(["measured \n(simulated)", "simulated\nfrom posterior"], bbox_to_anchor=(.22, 1), 
           handlelength=handlelength)

# Add Letters.
weight = "bold"
fontsize = 20
x = 0.1
dx1 = 0.38
dx2 = 0.65
y = 0.91
dy = 0.46
fig.text(x, y, "a", fontsize=fontsize, fontweight=weight)
fig.text(dx1, y, "b", fontsize=fontsize, fontweight=weight)
fig.text(dx2, y, "c", fontsize=fontsize, fontweight=weight)

fig.text(dx1, dy, "d", fontsize=fontsize, fontweight=weight)
plt.tight_layout();

# %%
for ftype in ["png", "pdf", "eps"]:
    fig.savefig(f"supp_fig1-sbi_evaluation.{ftype}", dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
